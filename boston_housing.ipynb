# %%
# description
# https://www.kaggle.com/c/boston-housing

# TensorFlow and tf.keras
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = tensorflow.keras.datasets.boston_housing.load_data(path='boston_housing.npz')

# %% [markdown]
# graph의 중간에 hidden layer도 추가 할 수 있는데 이는 더욱 복잡한 문제를 계산해내기 위함. 전체 layer의 갯수와 각각 layer의 node 갯수가 complexity를 결정. 다만 hidden layer를 추가할 때 마지막은 Dense(1)이 되어야 하는데 이는 출력값이 마지막에 1개이 이기 때문.

# %%
model = Sequential()
model.add(Dense(1, input_shape=[13]))
model.compile(optimizer='rmsprop', loss='mse')
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\fftth\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\fftth\Anaconda3\lib\site-packages\tensorflow\python\keras\utils\losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 1)                 14
# ...
# Total params: 14
# Trainable params: 14
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# input/output과 target 값을 구분할 필요 있음. 입력값을 넣어서 나온 출력값이 target값과 같지는 않음. 다만 그 차이인 error를 좋은 데이터를 많이 사용하거나 훈련 횟수를 높여서 줄여나가는 것.

# %%
model.fit(x_train, y_train, epochs=200)
# Out:
# Epoch 1/200
# 404/404 [==============================] - 0s 91us/sample - loss: 60.8365
# Epoch 2/200
# 404/404 [==============================] - 0s 84us/sample - loss: 60.5930
# Epoch 3/200
# 404/404 [==============================] - 0s 96us/sample - loss: 58.9651
# Epoch 4/200
# 404/404 [==============================] - 0s 94us/sample - loss: 57.9696
# Epoch 5/200
# 404/404 [==============================] - 0s 77us/sample - loss: 58.0900
# Epoch 6/200
# 404/404 [==============================] - 0s 104us/sample - loss: 56.3623
# Epoch 7/200
# 404/404 [==============================] - 0s 104us/sample - loss: 55.8654
# Epoch 8/200
# 404/404 [==============================] - 0s 99us/sample - loss: 54.7956
# Epoch 9/200
# 404/404 [==============================] - 0s 81us/sample - loss: 54.0823
# Epoch 10/200
# 404/404 [==============================] - 0s 114us/sample - loss: 53.9439
# Epoch 11/200
# 404/404 [==============================] - 0s 160us/sample - loss: 52.6441
# ...

# %% [markdown]
# x_train과 x_text를 따로 지정하는 이유는 모델을 테스트 할 때는 훈련 할 때 사용하지 않았던 데이터가 필요하기 때문.

# %%
model.evaluate(x_test, y_test)
# Out:
# 102/102 [==============================] - 0s 137us/sample - loss: 37.6240
# 37.623952977797565

# %%
print(model.input_shape)
print(model.output_shape)
# Out:
# (None, 13)
# (None, 1)

# %% [markdown]
# predict가 모델의 실제 상품화를 위해 사용하는 함수.

# %%
# INPUT::
# 1. crim: per capita crime rate by town.
# 2. zn: proportion of residential land zoned for lots over 25,000 sq.ft.
# 3. indus: proportion of non-retail business acres per town.
# 4. chas: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise).
# 5. nox: nitrogen oxides concentration (parts per 10 million).
# 6. rm: average number of rooms per dwelling.
# 7. age: proportion of owner-occupied units built prior to 1940.
# 8. dis: weighted mean of distances to five Boston employment centres.
# 9. rad: index of accessibility to radial highways.
# 10. tax: full-value property-tax rate per $10,000.
# 11. ptratio: pupil-teacher ratio by town.
# 12. black: 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town.
# 13. lstat: lower status of the population (percent).

# TARGET::
# medv: median value of owner-occupied homes in $1000s.

model.predict(np.array([0, 1, 50, 1, 0, 5, .5, 10, 1000, 100, 10, 100, 1]).reshape(1,13))
# Out:
# array([[204.9625]], dtype=float32)
